# %%
from gitsource import GithubRepositoryDataReader

reader = GithubRepositoryDataReader(
    repo_owner="DataTalksClub",
    repo_name="llm-zoomcamp",
    commit_id="8c1834d",
    allowed_extensions={"md"},
    filename_filter=lambda path: "/lessons/" in path,
)

files = reader.read()

# %%
documents = []

for file in files:
    doc = file.parse()
    documents.append(doc)

# %%
documents[0]
# Out:
# {'content': '# Introduction\n\nVideo: [Watch this lesson](https://www.youtube.com/watch?v=rQYyFxf1FWw&list=PL3MmuxUbc_hLZFNgSad56pDBKK8KO0XIv)\n\nIn this module, we\'ll build a working Retrieval-Augmented\nGeneration (RAG) system from scratch, step by step.\n\nWe write everything in plain Python. We build a small search index by\nhand and call the LLM ourselves. I want you to see every piece first.\nThat way you know what a framework does for you before you reach for\none.\n\nPlaces where you can find me:\n\n- [My substack](https://alexeyondata.substack.com/)\n- [LinkedIn](https://www.linkedin.com/in/agrigorev/)\n- [X](https://x.com/Al_Grigor)\n\n## LLMs\n\nAn LLM (Large Language Model) is a neural network trained on massive\namounts of text. Given a prompt, it generates a continuation - a\nplausible next piece of text.\n\nThink of your phone. When you type "how are" in WhatsApp, it suggests\n"you" as the next word. "How are you" is the most common continuation.\nYour phone uses a simple language model for that. It predicts the next\nword based on what you typed so far.\n\nA large language model does the same thing, but at a much larger scale.\nIt has billions of parameters and is trained on most of the text on the\ninternet. When it predicts the next word, it feels like you\'re talking\nto an intelligent being. It understands what you ask and gives\nmeaningful answers.\n\nIn this course, we treat LLMs as black boxes. We won\'t look inside or\ncover the theory, and we won\'t host a model ourselves. We use an LLM\nprovider and call it over an API. For us, an LLM is a box: text goes in,\ntext comes out.\n\nBut LLMs have limitations:\n\n- Knowledge cutoff: they only know what was in their training data.\n  If you ask about something that happened after training, they won\'t\n  know - or worse, they\'ll make something up.\n- No access to your data: they can\'t see your documents, databases,\n  or internal systems unless you provide that information.\n- Hallucinations: they sometimes produce confident-sounding answers\n  that are simply wrong.\n\n## The project\n\nRAG solves these problems by giving the LLM relevant documents at\nquestion time. We don\'t hope the model memorized the answer. We\nretrieve the right information and hand it to the LLM, and the model\ngenerates a grounded response. This lets us inject knowledge the model\nnever saw during training. That\'s why RAG is still the most common way\npeople use LLMs in the industry.\n\nTo make this concrete, we build a FAQ agent for our course. A student\nasks something like "when does the course start?" and the agent answers\nfrom the FAQ data we prepared.\n\nThis module has two parts.\n\nIn Part 1 (the next 9 lessons) we will:\n\n- Understand what RAG is and how it works\n- Build a search engine over a real FAQ dataset\n- Write a prompt that combines the user\'s question with search results\n- Wire it all together into a working RAG pipeline\n- Split ingestion and query into separate processes\n\nIn Part 2, we make the pipeline agentic. The LLM decides when and\nwhat to search, instead of running the same fixed flow every time.\n\nThe final code from this module is available in the\n[code/](../code/) directory.\n\n[← Back to module](../) | [Environment →](02-environment.md)',
#  'filename': '01-agentic-rag/lessons/01-intro.md'}

# %%
from minsearch import Index

index = Index(
    text_fields={'content':1.0},
    keyword_fields=['filename']
)
index.fit(documents)

# %%
question="How does the agentic loop keep calling the model until it stops?"

# %%
search_results = index.search(
    question,
    boost_dict={'content':1.0},
  
    num_results=5
)

# %%
search_results[0]
# Out:
# {'content': '# The Agentic Loop\n\nVideo: [Watch this lesson](https://www.youtube.com/watch?v=ePlQUcTPPjw&list=PL3MmuxUbc_hLZFNgSad56pDBKK8KO0XIv)\n\nIn the previous lesson, we did function calling by hand. We sent a\nmessage and got back a function call. We ran it, sent the result back,\nand got the answer.\n\nThat works for one function call. It breaks down when the model wants\nto search several times, or when the first search misses the answer.\nWe don\'t know in advance how many calls the model will want. So we\nneed a loop that keeps calling the model and running tools until it\'s\ndone. An agent is exactly that.\n\n## Anatomy of an agent\n\nWith the LLM in the driver\'s seat, we have an agent. It\'s an AI\nassistant whose goal is to help the user.\n\nAn agent has three parts:\n\n- Instructions, the role and behavior we want. We pass this as the\n  `developer` message. The better the instructions, the better the\n  agent helps.\n- Tools, the functions the agent can call to carry out the task. For\n  us that\'s only `search`.\n- Memory, the message history. We append every prompt, every model\n  output, and every tool result. The agent reads this to know what it\n  has already tried.\n\nEverything below is the code that wires these three together inside a\nloop.\n\n## A developer prompt\n\nSo far we\'ve relied on the model to figure out when to search. We make\nthat more reliable with a `developer` message that spells out how to\nbehave. This is where we give the agent its role. The same message\nalso pushes it toward multiple searches, so we get to watch the loop\nrun more than once.\n\n```python\ninstructions = """\nYou\'re a course teaching assistant.\nYou\'re given a question from a course student and your task is to answer it.\n\nIf you want to look up information, use the search function. \nUse as many keywords from the user question as possible when making first requests.\n\nMake multiple searches.\n\nTry to expand your search by using new keywords\nbased on the results you get from the search.\n\nAt the end, ask if there are other areas that the user wants to explore.\n""".strip()\n```\n\n## A function-call helper\n\nWe\'ll be running function calls repeatedly inside the loop, so let\'s\nwrap that in a small helper. It turns the JSON arguments into a Python\ndict, calls the right function, and serializes the result. We only\nhave one tool for now, so we dispatch on the function name directly.\n\n```python\ndef make_call(call):\n    args = json.loads(call.arguments)\n\n    if call.name == "search":\n        result = search(**args)\n\n    result_json = json.dumps(result, indent=2)\n\n    return {\n        "type": "function_call_output",\n        "call_id": call.call_id,\n        "output": result_json,\n    }\n```\n\nThe helper returns the exact structure the Responses API expects.\nWhen we add more tools later, we\'ll extend this with more `if`\nbranches (or switch to a registry).\n\n## Processing one response\n\nLet\'s process a single model response. We append each output entry to\nthe conversation, print any messages, and run any function calls.\nFunction-call results get appended too.\n\n```python\nquestion = "I just discovered the course. Can I join it?"\n\nmessages = [\n    {"role": "developer", "content": instructions},\n    {"role": "user", "content": question},\n]\n\nresponse = openai_client.responses.create(\n    model="gpt-5.4-mini",\n    input=messages,\n    tools=[search_tool],\n)\n\nmessages.extend(response.output)\nhas_function_calls = False\n\nfor item in response.output:\n    if item.type == "function_call":\n        print("function_call:", item.name, item.arguments)\n        call_output = make_call(item)\n        messages.append(call_output)\n        has_function_calls = True\n\n    elif item.type == "message":\n        print("ASSISTANT:")\n        print(item.content[0].text)\n```\n\nThe `has_function_calls` flag tells us whether the model needs another\nAPI call. If the response contains a functio ...
#  'filename': '01-agentic-rag/lessons/14-agentic-loop.md'}

# %% [markdown]
# ## Homework Questions

# %%
len(documents)
# Out:
# 72

# %% [markdown]
# ### 1. How many lesson pages (1 point)
#
# - 24
# - **72**
# - 240
# - 720

# %% [markdown]
# ### 2. Indexing and searching (1 point)
#
# - 01-agentic-rag/lessons/03-rag.md
# - **01-agentic-rag/lessons/14-agentic-loop.md**
# - 04-evaluation/lessons/13-llm-as-judge.md
# - 06-best-practices/lessons/02-hybrid-search.md

# %% [markdown]
# Now we will build a RAG assistant on top of this data. Let's use the rag helper script we prepared during the lessons:
#
# wget https://raw.githubusercontent.com/DataTalksClub/llm-zoomcamp/main/01-agentic-rag/code/rag_helper.py
# RAGBase was written for the FAQ schema (section/question/answer), while our documents have filename and content.
#
# Two solutions are possible:
#
# Implement the RAG flow yourself
# Take RAGBase and change the parts related to the FAQ schema - search (to use our index) and build_context
# Build a RAG over the index from Q2 and answer the query:
#
# How does the agentic loop keep calling the model until it stops?
#
# Use gpt-5.4-mini. How many input (prompt) tokens did we send to the model for this request?
#
#
# We count input tokens instead of price because the cost depends on the model and provider you use, but the size of the prompt we send is the same for everyone.
#
# Most LLM APIs report token usage on the response object (e.g. response.usage.input_tokens / prompt_tokens). We'll read the input tokens from there.
#
# You will need to modify the code for the rag helper to expose the usage.
#
# In the RAG Helper class, llm returns only the text. Modify it to return the whole response, and change rag to return both the answer and usage (as a tuple or create a small dataclass for that).

# %%
from rag_helper import RAGBase
from dotenv import load_dotenv
load_dotenv()

from openai import OpenAI
openai_client = OpenAI()
openai_client = OpenAI(
    api_key=api_key,
    base_url="https://openrouter.ai/api/v1"
)

# %%
from dotenv import load_dotenv
load_dotenv()

import os

api_key=os.getenv("OPENROUTER_API_KEY")
model="openai/gpt-oss-120b:free"

# %%
from openai import OpenAI

client = OpenAI(
    api_key=api_key,
    base_url="https://openrouter.ai/api/v1"
)
print(api_key[:15] if api_key else "NO KEY FOUND")
response = client.chat.completions.create(
    model="openai/gpt-oss-120b:free"
   ,
    messages=[
        {"role": "user", "content": "Write a Python function to search a SQLite database."}
    ]
)

print(response.choices[0].message.content)
# Out:
# sk-or-v1-5076b8
# Below is a **self‑contained, production‑ready** Python helper that lets you search any SQLite database with a flexible set of criteria.
# It demonstrates good practices such as:
#
# * Using **parameterised queries** (prevents SQL‑injection).
# * Managing the connection with a **context manager** (`with` statement) so the DB file is always closed cleanly.
# * Accepting **dynamic filters** (equality, range, LIKE, IN, etc.) without having to hard‑code SQL strings.
# * Returning rows as **dictionaries** (`sqlite3.Row`) for easy consumption (or optionally as plain tuples).
# * Optional **ordering**, **limit/offset**, and **debug logging**.
#
# ```python
# import sqlite3
# from typing import (
#     Any,
#     Dict,
#     Iterable,
#     List,
#     Sequence,
#     Tuple,
#     Union,
#     Optional,
#     Generator,
# )
# import logging
#
# # ----------------------------------------------------------------------
# # Configure a very small logger – callers can replace this configuration
# # ----------------------------------------------------------------------
# logger = logging.getLogger(__name__)
# if not logger.handlers:                # avoid duplicate handlers in notebooks
#     handler = logging.StreamHandler()
#     formatter = logging.Formatter(
#         "%(asctime)s %(levelname)s %(name)s – %(message)s"
#     )
#     handler.setFormatter(formatter)
#     logger.addHandler(handler)
# logger.setLevel(logging.INFO)          # set to DEBUG to see the generated SQL
#
#
# # ----------------------------------------------------------------------
# # Helper types
# # ----------------------------------------------------------------------
# FilterValue = Union[
#     Any,                                 # simple equality  (col = ?)
#     Tuple[Any, Any],                     # range (col BETWEEN ? AND ?)
#     Sequence[Any],                       # IN clause (col IN (...))
#     Dict[str, Any],                      # {"op": "...", "value": ...}
# ]
#
# OrderSpec = Tuple[str, str]  # ("column_name", "ASC"|"DESC")
#
#
# # ----------------------------------------------------------------------
# # Core function
# # ----------------------------------------------------------------------
# def search_sqlite(
#     db_path: str,
#     table: str,
#     *,
#     filters: Optional[Dict[str, FilterValue]] = None,
#     select: Optional[Sequence[str]] = None,
#     order_by: Optional[Sequence[OrderSpec]] = None,
#     limit: Optional[int] = None,
#     offset: Optional[int] = None,
#     as_dict: bool = True,
# ) -> List[Union[Dict[str, Any], Tuple[Any, ...]]]:
#     """
#     Execute a SELECT query against a SQLite database with dynamic WHERE clauses.
#
#     Parameters
#     ----------
#     db_path : str
#         Path to the SQLite file (or ``:memory:`` for an in‑memory DB).
#
#     table : str
#         Name of the table to query. **Do NOT** include user‑provided data in ``table``
#         unless you have validated it – SQLite identifiers cannot be safely bound
#         as parameters.
#
#     filters : dict, optional
#         Mapping ``column_name → value`` used to build the WHERE clause.
#         The value can be:
#
#         * ``value`` – simple equality (``col = ?``).
#         * ``(low, high)`` – range (``col BETWEEN ? AND ?``).
#         * ``[v1, v2, …]`` – IN list (``col IN (?, ?, …)``).
#         * ``{"op": "...", "value": ...}`` – custom operator, e.g.
#           ``{"op": "LIKE", "value": "%foo%"}``.
#
#         Columns with a value of ``None`` are ignored (use ``{"op": "IS", "value": None}``
#         if you really need ``col IS NULL``).
#
#     select : sequence of str, optional
#         Columns to return. ``None`` (default) returns all columns (``*``).
#
#     order_by : sequence of (column, direction) tuples, optional
#         Sort order – e.g. ``[("age", "DESC"), ("name", "ASC")]``.
#
#     limit : int, optional
#         Max number of rows to return.
#
#     offset : int, optional
#         Number of rows to skip (useful together with ``limit``).
#
#     as_dict : bool, default True
#         When ``True`` each row is returned as a ``dict`` (column name → value);
#         otherwise a plain tuple is returned.
#
#     Returns
#     -------
#     List[dict] or List[tuple]
#         The rows that match the criteria.
#
#     Raises
#     ------
#     sqlite3.Error
#         Propagates any SQLite error (e.g., malformed table name, bad column name,
#         syntax error in custom operators).
#
#     Example
#     -------
#     >>> rows = search_sqlite(
#     ...     "employees.db",
#     ...     "employees",
#     ...     filters={
#     ...         "department": "Engineering",
#     ...         "salary": (60000, 120000),               # BETWEEN
#     ...         "last_name": {"op": "LIKE", "value": "S%"},
#     ...         "status": ["active", "contract"]         # IN
#     ...     },
#     ...     order_by=[("salary", "DESC")],
#     ...     limit=10,
#     ... )
#     >>> for r in rows:
#     ...     print(r["first_name"], r["last_name"], r["salary"])
#     """
#     # ------------------------------------------------------------------
#     # 1️⃣ Build the SELECT clause
#     # ------------------------------------------------------------------
#     if select:
#         # Guard against empty sequence – fallback to '*'
#         columns = ", ".join([f'"{col}"' for col in select if col])
#         if not columns:
#             columns = "*"
#     else:
#         columns = "*"
#
#     sql = f'SELECT {columns} FROM "{table}"'   # table name is quoted (not a bind param)
#
#     # ------------------------------------------------------------------
#     # 2️⃣ Prepare WHERE clause and parameter list
#     # ------------------------------------------------------------------
#     params: List[Any] = []
#     if filters:
#         where_clauses: List[str] = []
#
#         for col, raw_val in filters.items():
#             # Skip columns with a plain ``None`` – user probably meant “no filter”.
#             if raw_val is None:
#                 continue
#
#             # Helper to safely quote column identifiers
#             col_quoted = f'"{col}"'
#
#             # 2a) Custom operator dict: {"op": "...", "value": ...}
#             if isinstance(raw_val, dict):
#                 op = raw_val.get("op", "=").upper()
#                 value = raw_val.get("value")
#                 if op == "IS" and value is None:
#                     where_clauses.append(f"{col_quoted} IS NULL")
#                 else:
#                     where_clauses.append(f"{col_quoted} {op} ?")
#                     params.append(value)
#                 continue
#
#             # 2b) Range tuple → BETWEEN
#             if isinstance(raw_val, tuple) and len(raw_val) == 2:
#                 low, high = raw_val
#                 where_clauses.append(f"{col_quoted} BETWEEN ? AND ?")
#                 params.extend([low, high])
#                 continue
#
#             # 2c) Sequence (list, set, etc.) → IN
#             if isinstance(raw_val, (list, set, tuple)):
#                 # empty IN list would be a syntax error – treat as FALSE
#                 if not raw_val:
#                     where_clauses.append("0")   # always false
#                 else:
#                     placeholders = ", ".join(["?"] * len(raw_val))
#                     where_clauses.append(f"{col_quoted} IN ({placeholders})")
#                     params.extend(list(raw_val))
#                 continue
#
#             # 2d) Simple equality
#             where_clauses.append(f"{col_quoted} = ?")
#             params.append(raw_val)
#
#         if where_clauses:
#             sql += " WHERE " + " AND ".join(where_clauses)
#
#     # ------------------------------------------------------------------
#     # 3️⃣ ORDER BY, LIMIT, OFFSET
#     # ------------------------------------------------------------------
#     if order_by:
#         order_terms = []
#         for col, direction in order_by:
#             direction = direction.upper()
#             if direction not in {"ASC", "DESC"}:
#                 raise ValueError(f"Invalid order direction: {direction!r}")
#             order_terms.append(f'"{col}" {direction}')
#         sql += " ORDER BY " + ", ".join(order_terms)
#
#     if limit is not None:
#         if limit < 0:
#             raise ValueError("limit must be non‑negative")
#         sql += " LIMIT ?"
#         params.append(limit)
#
#         if offset is not None:
#             if offset < 0:
#                 raise ValueError("offset must be non‑negative")
#             sql += " OFFSET ?"
#             params.append(offset)
#     elif offset is not None:
#         # SQLite allows OFFSET without LIMIT, but we require an explicit LIMIT
#         raise ValueError("offset cannot be used without limit")
#
#     # ------------------------------------------------------------------
#     # 4️⃣ Debug output (optional)
#     # ------------------------------------------------------------------
#     logger.debug("Generated SQL: %s", sql)
#     logger.debug("Parameters: %s", params)
#
#     # ------------------------------------------------------------------
#     # 5️⃣ Execute the query
#     # ------------------------------------------------------------------
#     rows: List[Union[Dict[str, Any], Tuple[Any, ...]]] = []
#     try:
#         # The `detect_types` flag enables automatic conversion of SQLite types
#         # (e.g., timestamps) if you register adapters/converters elsewhere.
#         with sqlite3.connect(db_path, detect_types=sqlite3.PARSE_DECLTYPES) as conn:
#             conn.row_factory = sqlite3.Row if as_dict else None
#             cur = conn.cursor()
#             cur.execute(sql, params)
#
#             # Fetch all at once; for huge result sets you could yield rows
#             # with a generator instead.
#             rows = cur.fetchall()
#     except sqlite3.Error as exc:
#         logger.error("SQLite error while executing query: %s", exc)
#         raise
#
#     # ------------------------------------------------------------------
#     # 6️⃣ Convert Row objects to plain dicts (if requested)
#     # ------------------------------------------------------------------
#     if as_dict:
#         rows = [dict(row) for row in rows]   # type: ignore[arg-type]
#
#     return rows
# ```
#
# ### How to use it
#
# ```python
# if __name__ == "__main__":
#     # Example 1 – simple equality + LIKE
#     result = search_sqlite(
#         db_path="library.db",
#         table="books",
#         filters={
#             "author": "Jane Austen",
#             "title": {"op": "LIKE", "value": "%Pride%"},
#         },
#         order_by=[("published_year", "DESC")],
#         limit=5,
#     )
#     for row in result:
#         print(row["title"], row["published_year"])
#
#     # Example 2 – range + IN + custom operator
#     result = search_sqlite(
#         db_path="sales.db",
#         table="orders",
#         filters={
#             "order_date": ("2023-01-01", "2023-12-31"),          # BETWEEN
#             "status": ["shipped", "delivered"],                # IN
#             "total": {"op": ">", "value": 1000},                # > 1000
#         },
#         select=("order_id", "customer_id", "total"),
#         order_by=[("total", "DESC")],
#         limit=10,
#     )
#     for row in result:
#         print(row)
# ```
#
# ### Why this design?
#
# | Concern | How the code addresses it |
# |---------|---------------------------|
# | **SQL injection** | All values are passed as *parameters* (`?`). Only table/column names are interpolated, and they are quoted (`"col"`). You should validate any user‑provided identifier before calling the function. |
# | **Resource cleanup** | `with sqlite3.connect(...) as conn:` guarantees `commit/close` even on exceptions. |
# | **Result usability** | `sqlite3.Row` → `dict` gives you `row["col"]` access, which is far nicer than tuple indexes. |
# | **Flexibility** | Supports equality, `BETWEEN`, `IN`, `LIKE`, custom operators, ordering, paging, and arbitrary column selection. |
# | **Extensibility** | Adding a new operator is as easy as extending the `if isinstance(raw_val, dict):` block. |
# | **Performance** | For very large result sets you could change the final `fetchall()` to a generator (`yield from cur`). |
#
# Feel free to copy the function into your own module, adapt the logging level, or wrap it in a class if you need connection pooling or transaction handling. Happy querying!

# %%
question
# Out:
# 'How does the agentic loop keep calling the model until it stops?'

# %%
assistant = RAGBase(index, openai_client, model=model)
assistant.rag(question)
# Out:
# ('The loop is a simple\u202f`while True`\u202fthat repeatedly sends the current message history to the model, runs any tool calls that come back, and then checks whether the model asked for another tool.\n\n```python\nwhile True:\n    has_function_calls = False\n\n    response = openai_client.responses.create(\n        model=...,\n        input=messages,\n        tools=[search_tool],\n    )\n    messages.extend(response.output)\n\n    for item in response.output:\n        if item.type == "function_call":\n            # run the tool, append its result\n            call_output = make_call(item)\n            messages.append(call_output)\n            has_function_calls = True\n        elif item.type == "message":\n            # print the assistant’s reply\n            ...\n\n    if not has_function_calls:      # ← exit condition\n        break\n```\n\n* Each iteration sends the full `messages` list (the\u202f**memory**) to the LLM.  \n* If the response contains a `function_call`, the code executes the tool (`make_call`) and appends the tool’s output back into `messages`. The flag `has_function_calls` is set to\u202f`True`.  \n* Because a new tool result has been added, the next iteration will see it and the model can decide on a follow‑up action.  \n* When a turn finishes with **no** function calls (`has_function_calls` stays `False`), the loop breaks—that turn is the model’s final answer.\n\nThus the loop “keeps calling the model until it stops” by repeatedly:\n1. sending the updated conversation,\n2. executing any tool calls that the model requests, and\n3. exiting only when a response comes back with no further tool calls.',
#  7094,
#  404)

# %% [markdown]
# ### 3. RAG (1 point)
#
# - 700
# - **7000**
# - 70000
# - 700000

# %%
from gitsource import chunk_documents

chunks = chunk_documents(documents, size=2000, step=1000)

# %%
len(chunks)
# Out:
# 295

# %%
chunks[1]
# Out:
# {'start': 1000,
#  'content': 'the next\nword based on what you typed so far.\n\nA large language model does the same thing, but at a much larger scale.\nIt has billions of parameters and is trained on most of the text on the\ninternet. When it predicts the next word, it feels like you\'re talking\nto an intelligent being. It understands what you ask and gives\nmeaningful answers.\n\nIn this course, we treat LLMs as black boxes. We won\'t look inside or\ncover the theory, and we won\'t host a model ourselves. We use an LLM\nprovider and call it over an API. For us, an LLM is a box: text goes in,\ntext comes out.\n\nBut LLMs have limitations:\n\n- Knowledge cutoff: they only know what was in their training data.\n  If you ask about something that happened after training, they won\'t\n  know - or worse, they\'ll make something up.\n- No access to your data: they can\'t see your documents, databases,\n  or internal systems unless you provide that information.\n- Hallucinations: they sometimes produce confident-sounding answers\n  that are simply wrong.\n\n## The project\n\nRAG solves these problems by giving the LLM relevant documents at\nquestion time. We don\'t hope the model memorized the answer. We\nretrieve the right information and hand it to the LLM, and the model\ngenerates a grounded response. This lets us inject knowledge the model\nnever saw during training. That\'s why RAG is still the most common way\npeople use LLMs in the industry.\n\nTo make this concrete, we build a FAQ agent for our course. A student\nasks something like "when does the course start?" and the agent answers\nfrom the FAQ data we prepared.\n\nThis module has two parts.\n\nIn Part 1 (the next 9 lessons) we will:\n\n- Understand what RAG is and how it works\n- Build a search engine over a real FAQ dataset\n- Write a prompt that combines the user\'s question with search results\n- Wire it all together into a working RAG pipeline\n- Split ingestion and query into separate processes\n\nIn Part 2, we make the pipeline agentic. The LLM decides when and\nwhat to search, instead of ',
#  'filename': '01-agentic-rag/lessons/01-intro.md'}

# %% [markdown]
# ### 4. Chunking (1 point)
#
# - 70
# - **295**
# - 1100
# - 4500

# %%
index.fit(chunks)

# %%
assistant = RAGBase(index, openai_client, model=model)
assistant.rag(question)
# Out:
# ('The agentic loop is just a **while‑True loop** that repeats the same three steps over and over:\n\n1. **Send the current message history to the LLM** (including any developer / instruction messages and everything that has happened so far).  \n2. **Inspect the model’s output**:  \n   * If the output contains a `function_call` item, the loop executes that tool (e.g., `search`) and appends the tool’s result back into the `messages` list. It also sets a flag (`has_function_calls = True`).  \n   * If the output contains a normal `message` item, the text is shown to the user and stored as the latest answer.  \n3. **Check the flag** – after the model’s turn, if **no function‑call items were returned** (`has_function_calls` is still `False`), the loop breaks; otherwise it goes back to step\u202f1.\n\nBecause the flag is reset to `False` at the start of each iteration, the loop will keep invoking the model as long as the model keeps requesting tools. The only exit condition is a turn where the model produces a final answer **without any tool calls**. (In practice you can add extra safety nets such as a max‑iteration count, token budget, or time limit, but the core mechanism is the `has_function_calls` flag.)',
#  2279,
#  315)

# %% [markdown]
# ### 5. RAG with chunking (1 point)
#
# - about the same
# - **3x fewer**
# - 10x fewer
# - 30x fewer

# %%
from toyaikit.llm import OpenAIClient
from toyaikit.tools import Tools
from toyaikit.chat import IPythonChatInterface
from toyaikit.chat.runners import OpenAIResponsesRunner, DisplayingRunnerCallback

# %%
def search(query: str) -> dict[str, str]:
    """
    Search the FAQ database for entries matching the given query.
    """
    return index.search(
        query,
        num_results=5,
        boost_dict = {'content':1.0}
    )

# %%
search_tool = {
    "type": "function",
    'name': 'search',
    'description': 'Search the FAQ database for entries matching the given query.',
    'parameters': {
        "type": "object",
        "properties": {
            'query': {
                "type": "string",
                'description': 'Search query text to look up in the course FAQ.'
            }
        },
        "required": ["query"],
        'additionalProperties': False
    }
}

# %%
agent_tools = Tools()
agent_tools.add_tool(search, search_tool)

# %%
agent_tools.get_tools()
# Out:
# [{'type': 'function',
#   'name': 'search',
#   'description': 'Search the FAQ database for entries matching the given query.',
#   'parameters': {'type': 'object',
#    'properties': {'query': {'type': 'string',
#      'description': 'Search query text to look up in the course FAQ.'}},
#    'required': ['query'],
#    'additionalProperties': False}}]

# %%
chat_interface = IPythonChatInterface()
callback = DisplayingRunnerCallback(chat_interface)

# %% [markdown]
# ### 6. Turning it into an agent (1 point)
#
# - 0
# - 4
# - **10**
# - 20
